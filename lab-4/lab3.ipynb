# %% [markdown]
# # Zadanie 3
#
# Zadanie: "regresja i klasyfikacja"
#
# Autor: Jakub Mazurkiewicz (300226)
#
# ## Wczytywanie danych

# %%
import pandas as pd
import sklearn.model_selection as sms

with open('breast-cancer.data', 'r') as file:
    x = pd.read_csv(file)
    y = range(len(x))
    
x_train, x_test, y_train, y_test = sms.train_test_split(x, y, test_size=0.5)
x_train, x_val, y_train, y_val = sms.train_test_split(x_train, y_train, test_size=0.5)

# %% [markdown]
# ### Uzyskany zbiór trenujący

# %%
x_train
# Out:
#                     class    age menopause tumor-size inv-nodes node-caps  \
# 239     recurrence-events  40-49   premeno      20-24       3-5       yes
# 165  no-recurrence-events  40-49   premeno      20-24       3-5        no
# 235     recurrence-events  50-59   premeno      25-29       3-5       yes
# 127  no-recurrence-events  30-39   premeno      25-29       6-8       yes
# 204     recurrence-events  50-59   premeno      25-29       0-2        no
# ..                    ...    ...       ...        ...       ...       ...
# 265     recurrence-events  30-39   premeno      35-39      9-11       yes
# 257     recurrence-events  40-49   premeno      20-24       3-5       yes
# 219     recurrence-events  30-39   premeno      15-19       0-2        no
# 135  no-recurrence-events  30-39   premeno      20-24       3-5        no
# 200  no-recurrence-events  60-69      ge40      25-29       0-2        no
#
#      deg-malig breast breas-quad irradiat
# ...

# %% [markdown]
# ### Uzyskany zbiór walidacyjny

# %%
x_val
# Out:
#                     class    age menopause tumor-size inv-nodes node-caps  \
# 16   no-recurrence-events  40-49   premeno      15-19       0-2        no
# 40   no-recurrence-events  50-59      ge40      20-24       0-2        no
# 172  no-recurrence-events  60-69      ge40      30-34       6-8       yes
# 202     recurrence-events  40-49   premeno      40-44       0-2        no
# 225     recurrence-events  40-49      ge40      20-24       3-5        no
# ..                    ...    ...       ...        ...       ...       ...
# 45   no-recurrence-events  50-59      ge40      30-34       0-2        no
# 2    no-recurrence-events  40-49   premeno      20-24       0-2        no
# 17   no-recurrence-events  50-59   premeno      30-34       0-2        no
# 177  no-recurrence-events  60-69      ge40      10-14       0-2        no
# 262     recurrence-events  60-69      ge40      25-29       0-2        no
#
#      deg-malig breast breas-quad irradiat
# ...

# %% [markdown]
# ### Uzyskany zbiór testowy

# %%
x_test
# Out:
#                     class    age menopause tumor-size inv-nodes node-caps  \
# 82   no-recurrence-events  60-69      ge40      15-19       0-2        no
# 237     recurrence-events  40-49   premeno      25-29       0-2        no
# 34   no-recurrence-events  50-59      ge40      10-14       0-2        no
# 245     recurrence-events  30-39   premeno      30-34      9-11        no
# 141  no-recurrence-events  50-59   premeno      20-24       3-5       yes
# ..                    ...    ...       ...        ...       ...       ...
# 4    no-recurrence-events  40-49   premeno        0-4       0-2        no
# 90   no-recurrence-events  30-39   premeno        0-4       0-2        no
# 206     recurrence-events  50-59      ge40      30-34       0-2        no
# 159  no-recurrence-events  40-49   premeno      35-39       0-2        no
# 256     recurrence-events  40-49   premeno      30-34       0-2        no
#
#      deg-malig breast breas-quad irradiat
# ...
